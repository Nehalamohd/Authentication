# %% [markdown]
# <a href="https://colab.research.google.com/github/Nehalamohd/Authentication/blob/main/Untitled42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NLP PROJECT

# %%
# import the library
import pandas as pd

# %%
#take the file
df=pd.read_csv('/content/vaccination_tweets[1].csv')

# %%
#to show first 5 row
df.head()
# Out:
#                     id             user_name              user_location  \
# 0  1340539111971516416            Rachel Roh  La Crescenta-Montrose, CA
# 1  1338158543359250433           Albert Fong          San Francisco, CA
# 2  1337858199140118533              eli🇱🇹🇪🇺👌                   Your Bed
# 3  1337855739918835717         Charles Adler     Vancouver, BC - Canada
# 4  1337854064604966912  Citizen News Channel                        NaN
#
#                                     user_description         user_created  \
# 0  Aggregator of Asian American news; scanning di...  2009-04-08 17:52:46
# 1  Marketing dude, tech geek, heavy metal & '80s ...  2009-09-21 15:27:30
# 2                                     heil, hydra 🖐☺  2020-06-25 23:30:28
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  2008-09-10 11:28:53
# 4  Citizen News Channel bringing you an alternati...  2020-04-23 17:58:42
#
#    user_followers  user_friends  user_favourites  user_verified  \
# ...

# %%
#perform EDA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11020 entries, 0 to 11019
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                11020 non-null  int64
#  1   user_name         11020 non-null  object
#  2   user_location     8750 non-null   object
#  3   user_description  10340 non-null  object
#  4   user_created      11020 non-null  object
#  5   user_followers    11020 non-null  int64
#  6   user_friends      11020 non-null  int64
#  7   user_favourites   11020 non-null  int64
#  8   user_verified     11020 non-null  bool
#  9   date              11020 non-null  object
#  10  text              11020 non-null  object
#  11  hashtags          8438 non-null   object
#  12  source            11019 non-null  object
#  13  retweets          11020 non-null  int64
#  14  favorites         11020 non-null  int64
#  15  is_retweet        11020 non-null  bool
# ...

# %%
#for checking null values
df.isnull().sum()
# Out:
# id                     0
# user_name              0
# user_location       2270
# user_description     680
# user_created           0
# user_followers         0
# user_friends           0
# user_favourites        0
# user_verified          0
# date                   0
# text                   0
# hashtags            2582
# source                 1
# retweets               0
# favorites              0
# is_retweet             0
# dtype: int64

# %%
#check colm name
df.columns
# Out:
# Index(['id', 'user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'retweets', 'favorites',
#        'is_retweet'],
#       dtype='object')

# %%
#remove columns
df = df.drop(['id', 'user_name', 'user_location', 'user_description', 'user_created',
       'user_followers', 'user_friends', 'user_favourites', 'user_verified',
       'date', 'hashtags', 'source', 'retweets', 'favorites',
       'is_retweet'], axis=1)

# %%
df.head()
# Out:
#                                                 text
# 0  Same folks said daikon paste could treat a cyt...
# 1  While the world has been on the wrong side of ...
# 2  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  Facts are immutable, Senator, even when you're...
# 4  Explain to me again why we need a vaccine @Bor...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11020 entries, 0 to 11019
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    11020 non-null  object
# dtypes: object(1)
# memory usage: 86.2+ KB

# %%
# for statistic count
df.describe()
# Out:
#                                                      text
# count                                               11020
# unique                                              11013
# top     #Covid19 Vaccine Rollout Needs Spark Even More...
# freq                                                    5

# %%
from collections import Counter
import matplotlib.pyplot as plt

words = ' '.join(df['text']).lower().split()
word_counts = Counter(words)
top_20_words = word_counts.most_common(20)

plt.figure(figsize=(12, 6))
plt.bar(*zip(*top_20_words))
plt.xticks(rotation=45, ha='right')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 Words in Tweets')
plt.show()

# %%
df['text_length'] = df['text'].apply(len)
df['word_count'] = df['text'].apply(lambda x: len(x.split()))

# Plot distribution
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df['text_length'], bins=30)
plt.title("Distribution of Tweet Lengths")
plt.show()

# %%
# here from this hist graph we got the length of each writing is around  long(140) character tweets

# %%
df.head()
# Out:
#                                                 text  text_length  word_count
# 0  Same folks said daikon paste could treat a cyt...           97          12
# 1  While the world has been on the wrong side of ...          140          21
# 2  #coronavirus #SputnikV #AstraZeneca #PfizerBio...          140          15
# 3  Facts are immutable, Senator, even when you're...          140          20
# 4  Explain to me again why we need a vaccine @Bor...          135          14

# %%
# Plot histogram of word counts
plt.figure(figsize=(8, 5))
sns.histplot(df['word_count'], bins=30, kde=False, color='skyblue')
plt.title("Distribution of Word Counts in Tweets")
plt.xlabel("Number of Words")
plt.ylabel("Number of Tweets")
plt.show()

# %%
#Tweets are mostly medium length—good for NLP models like LSTM or CNN.

# %%
#hashtag
import re
df['hashtags'] = df['text'].apply(lambda x: re.findall(r'#\w+', x))
print(df[['hashtags']])
# Out:
#                                                 hashtags
# 0                                      [#PfizerBioNTech]
# 1                                                     []
# 2      [#coronavirus, #SputnikV, #AstraZeneca, #Pfize...
# 3                                                     []
# 4           [#whereareallthesickpeople, #PfizerBioNTech]
# ...                                                  ...
# 11015                                                 []
# 11016                                  [#PfizerBioNTech]
# 11017                                                 []
# 11018             [#PfizerBioNTech, #Paxlovid, #COVID19]
# 11019                                                 []
#
# [11020 rows x 1 columns]

# %%
# by using hashtag we have to decide what the line mension about

# %%
# to show  most frequent words in the text column

# %%
#wordcloud
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# combine all text data from the 'text' column
all_text = ' '.join(df['text'].dropna())

# generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')  # Smooth interpolation for better visualization
plt.axis('off')  # Hide axes
plt.title("Most Frequent Words in Tweets")
plt.show()

# %%
df.head()
# Out:
#                                                 text  text_length  word_count
# 0  Same folks said daikon paste could treat a cyt...           97          12
# 1  While the world has been on the wrong side of ...          140          21
# 2  #coronavirus #SputnikV #AstraZeneca #PfizerBio...          140          15
# 3  Facts are immutable, Senator, even when you're...          140          20
# 4  Explain to me again why we need a vaccine @Bor...          135          14

# %%
# import library for preprocessing
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk.corpus import stopwords
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
# preprocess the text
def preprocessing(text):
  text=text.lower()
  text=re.sub(r'[^A_za_z\w\s#]','',text)
  text_tokens = word_tokenize(text)
  filtered_text = [lemmatizer.lemmatize(w) for w in text_tokens if not w in stop_words]
  return " ".join(filtered_text)

# %%
df.text=df['text'].apply(preprocessing)

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of                                                     text  text_length  \
# 0      folk said daikon paste could treat cytokine st...           97
# 1      world wrong side history year hopefully bigges...          140
# 2      # coronavirus # sputnikv # astrazeneca # pfize...          140
# 3      fact immutable senator even youre ethically st...          140
# 4      explain need vaccine borisjohnson matthancock ...          135
# ...                                                  ...          ...
# 11015  number covid19 case today 17 november 2021 rem...          140
# 11016                        first dose # pfizerbiontech           28
# 11017  number covid19 case today 16 november 2021 rem...          140
# 11018  # pfizerbiontech developed new pill # paxlovid...          140
# 11019  number covid19 case today 15 november 2021 rem...          140
#
#        word_count                                           hashtags
# ...

# %%
df = df.drop_duplicates('text')

# %%
df.head()
# Out:
#                                                 text  text_length  word_count  \
# 0  folk said daikon paste could treat cytokine st...           97          12
# 1  world wrong side history year hopefully bigges...          140          21
# 2  # coronavirus # sputnikv # astrazeneca # pfize...          140          15
# 3  fact immutable senator even youre ethically st...          140          20
# 4  explain need vaccine borisjohnson matthancock ...          135          14
#
#                                             hashtags
# 0                                  [#PfizerBioNTech]
# 1                                                 []
# 2  [#coronavirus, #SputnikV, #AstraZeneca, #Pfize...
# 3                                                 []
# 4       [#whereareallthesickpeople, #PfizerBioNTech]

# %%
#for sentimental analysis

# %%
# !pip install vaderSentiment
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.7 MB/s eta 0:00:00
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
analyzer.polarity_scores(df)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# use textblob
from textblob import TextBlob

# %%
def polarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df.loc[:, 'polarity']= df['text'].apply(polarity)

# %%
df.head(5)
# Out:
#                                                 text  text_length  word_count  \
# 0  folk said daikon paste could treat cytokine st...           97          12
# 1  world wrong side history year hopefully bigges...          140          21
# 2  # coronavirus # sputnikv # astrazeneca # pfize...          140          15
# 3  fact immutable senator even youre ethically st...          140          20
# 4  explain need vaccine borisjohnson matthancock ...          135          14
#
#                                             hashtags  polarity
# 0                                  [#PfizerBioNTech]       0.0
# 1                                                 []      -0.5
# 2  [#coronavirus, #SputnikV, #AstraZeneca, #Pfize...       0.0
# 3                                                 []       0.1
# 4       [#whereareallthesickpeople, #PfizerBioNTech]       0.0

# %%
def sentiment(label):
    if label <0:
        return "Negative"
    elif label ==0:
        return "Neutral"
    elif label>0:
        return "Positive"

# %%
df['sentiment'] = df['polarity'].apply(sentiment)
# Out:
# <ipython-input-59-71dedcd10fde>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment'] = df['polarity'].apply(sentiment)

# %%
df.head()
# Out:
#                                                 text  text_length  word_count  \
# 0  folk said daikon paste could treat cytokine st...           97          12
# 1  world wrong side history year hopefully bigges...          140          21
# 2  # coronavirus # sputnikv # astrazeneca # pfize...          140          15
# 3  fact immutable senator even youre ethically st...          140          20
# 4  explain need vaccine borisjohnson matthancock ...          135          14
#
#                                             hashtags  polarity sentiment
# 0                                  [#PfizerBioNTech]       0.0   Neutral
# 1                                                 []      -0.5  Negative
# 2  [#coronavirus, #SputnikV, #AstraZeneca, #Pfize...       0.0   Neutral
# 3                                                 []       0.1  Positive
# 4       [#whereareallthesickpeople, #PfizerBioNTech]       0.0   Neutral

# %%
#to show the count of polarity
fig = plt.figure(figsize=(5,5))
sns.countplot(x='sentiment', data = df)
# Out:
# <Axes: xlabel='sentiment', ylabel='count'>

# %%
#using pie chart
fig = plt.figure(figsize=(7,7))
colors = ("yellowgreen", "gold", "red")
wp = {'linewidth':2, 'edgecolor':"black"}
tags = df['sentiment'].value_counts()
explode = (0.1,0.1,0.1)
tags.plot(kind='pie', autopct='%1.1f%%', shadow=True, colors = colors,
         startangle=90, wedgeprops = wp, explode = explode, label='')
plt.title('Distribution of sentiments')
# Out:
# Text(0.5, 1.0, 'Distribution of sentiments')

# %%
#for getting positive feedback
pos_tweets = df[df.sentiment == 'Positive']
pos_tweets = pos_tweets.sort_values(['polarity'], ascending= False)
pos_tweets.head()
# Out:
#                                                    text  text_length  \
# 11    cnnbrk # covid19 # covidvaccine # vaccine # co...          139
# 7470  wonderful news # pfizerbiontech # covidvaccine...           72
# 4417  best feeling got # covidvaccine let keep going...          125
# 2308  thankful get covid vaccine today impressed org...          140
# 2217  dr marc siegel covid vaccination increase rapi...          140
#
#       word_count                                           hashtags  polarity  \
# 11            15  [#COVID19, #CovidVaccine, #vaccine, #Corona, #...       1.0
# 7470           6                   [#PfizerBioNTech, #CovidVaccine]       1.0
# 4417          15     [#CovidVaccine, #vaccination, #PfizerBioNTech]       1.0
# 2308          19                                                 []       1.0
# 2217          19                                                 []       1.0
#
#      sentiment
# 11    Positive
# 7470  Positive
# 4417  Positive
# ...

# %%
#for cloudword of positive feedback
text = ' '.join([word for word in pos_tweets['text']])
plt.figure(figsize=(20,15), facecolor='None')
wordcloud = WordCloud(max_words=500, width=1600, height=800).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Most frequent words in positive tweets', fontsize=19)
plt.show()

# %%
# for negative tweets
neg_tweets = df[df.sentiment == 'Negative']
neg_tweets = neg_tweets.sort_values(['polarity'], ascending= False)
neg_tweets.head()
# Out:
#                                                    text  text_length  \
# 2912  work skilled nursing facility got first vaccin...          140
# 7256  200321 752308 vaccination new daily record dai...          134
# 7715  got first dose less waiting time airport vacci...          134
# 7157  nas_k27 second dose due end next month well fa...           79
# 2907  2015 worried absence mrna vaccine challenge wa...          139
#
#       word_count           hashtags  polarity sentiment
# 2912          24                 [] -0.003333  Negative
# 7256          17                 [] -0.003409  Negative
# 7715          22                 [] -0.005556  Negative
# 7157          15  [#PfizerBioNTech] -0.006250  Negative
# 2907          21                 [] -0.006250  Negative

# %%
#for nuetral
neutral_tweets = df[df.sentiment == 'Neutral']
neutral_tweets = neutral_tweets.sort_values(['polarity'], ascending= False)
neutral_tweets.head()
# Out:
#                                                     text  text_length  \
# 11019  number covid19 case today 15 november 2021 rem...          140
# 0      folk said daikon paste could treat cytokine st...           97
# 10988  tommy got vaxxed # vaxxed # pfizerbiontech htt...           72
# 10987  # covid19 # vaccinesideeffects # vaccine # pfi...          140
# 10986  # nstworld # iraq said received 12 million dos...          140
#
#        word_count                                           hashtags  \
# 11019          19                                                 []
# 0              12                                  [#PfizerBioNTech]
# 10988           7                         [#vaxxed, #pfizerbiontech]
# 10987          14  [#Covid19, #VaccineSideEffects, #Vaccines, #Pf...
# 10986          18  [#NSTworld, #Iraq, #PfizerBioNTech, #Covid19, ...
#
#        polarity sentiment
# 11019       0.0   Neutral
# 0           0.0   Neutral
# 10988       0.0   Neutral
# ...

# %%
text = ' '.join([word for word in neutral_tweets['text']])
plt.figure(figsize=(20,15), facecolor='None')
wordcloud = WordCloud(max_words=500, width=1600, height=800).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Most frequent words in neutral tweets', fontsize=19)
plt.show()

# %%
#NAMED ENTITY RECOGINITION

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
def extract_named_entities(text):
    doc = nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# %%
df['entities'] = df['text'].apply(extract_named_entities)
# Out:
# <ipython-input-121-95b2ef52887d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['entities'] = df['text'].apply(extract_named_entities)

# %%
print(df[['entities']].head())
# Out:
#                                             entities
# 0                         [(pfizerbiontech, PERSON)]
# 1                                                 []
# 2  [(#, CARDINAL), (#, CARDINAL), (#, CARDINAL), ...
# 3                                    [(1, CARDINAL)]
# 4  [(#, CARDINAL), (pfizerbiontech httpstcokxbsro...

# %%
# for converting words to numeric here use tfidf vectorization
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vector=TfidfVectorizer()

# %%
x=vector.fit_transform(df['text'])

# %%
y=df['sentiment']

# %%
#train the model
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Out:
# (8788, 26264)

# %%
print("Size of x_train:", (x_train.shape))
print("Size of y_train:", (y_train.shape))
print("Size of x_test:", (x_test.shape))
print("Size of y_test:", (y_test.shape))
# Out:
# Size of x_train: (8788, 26264)
# Size of y_train: (8788,)
# Size of x_test: (2198, 26264)
# Size of y_test: (2198,)

# %%
#here first model is logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
logreg_pred = logreg.predict(x_test)

# %%
logreg_acc = accuracy_score(logreg_pred, y_test)
logreg_acc
# Out:
# 0.835304822565969

# %%
print(confusion_matrix(y_test, logreg_pred))
print("\n")
print(classification_report(y_test, logreg_pred))
# Out:
# [[  31  145   36]
#  [   3 1060   15]
#  [   6  157  745]]
#
#
#               precision    recall  f1-score   support
#
#     Negative       0.78      0.15      0.25       212
#      Neutral       0.78      0.98      0.87      1078
#     Positive       0.94      0.82      0.87       908
#
#     accuracy                           0.84      2198
#    macro avg       0.83      0.65      0.66      2198
# weighted avg       0.84      0.84      0.81      2198

# %%
#to plot the confusion_matrix
cm = confusion_matrix(y_test, logreg_pred, labels=logreg.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=logreg.classes_)
disp.plot()

# %%
# secoond model is SVC

# %%
from sklearn.svm import LinearSVC

# %%
SVCmodel = LinearSVC()
SVCmodel.fit(x_train, y_train)
# Out:
# LinearSVC()

# %%
svc_pred = SVCmodel.predict(x_test)
svc_acc = accuracy_score(svc_pred, y_test)
svc_acc
# Out:
# 0.89171974522293

# %%
#here is the third model Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model=MultinomialNB()

# %%
model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred_model=model.predict(x_test)

# %%
accuracy_score_naive=accuracy_score(y_pred_model,y_test)
accuracy_score_naive
# Out:
# 0.7989080982711556

# %%
model_names = ['Naive Bayes', 'SVC', 'Logistic Regression']
accuracies = [0.7989, 0.8917, 0.8353]  # Rounded values for clarity in the plot

# %%
plt.figure(figsize=(8, 6))
plt.bar(model_names, accuracies, color=['skyblue', 'lightgreen', 'salmon'])

# Add labels and title
plt.title('Model Comparison - Accuracy')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.ylim(0, 1)  # accuracy is between 0 and 1
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#so model svc gives high performance as compared with other two model like logistic regression and naive bayes
#svc model with 0.89
#log reg with 0.83
#navie bayes with 0.7
